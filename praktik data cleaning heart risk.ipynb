# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"D:\Dhika Ramadhan Saputra\Data Analist\Kebutuhan\heart_attack_risk_dataset.csv")
df
# Out:
#        Age  Gender  Smoking  Alcohol_Consumption Physical_Activity_Level  \
# 0       69  Female        1                    0                Moderate
# 1       32    Male        0                    0                Moderate
# 2       89    Male        0                    1                Moderate
# 3       78    Male        0                    1                Moderate
# 4       38  Female        1                    0                Moderate
# ...    ...     ...      ...                  ...                     ...
# 49995   21    Male        0                    0                     Low
# 49996   35  Female        0                    0                     Low
# 49997   46    Male        0                    1                    High
# 49998   56    Male        0                    1                     Low
# 49999   72    Male        0                    0                    High
#
#          BMI  Diabetes  Hypertension  Cholesterol_Level  Resting_BP  \
# ...

# %%
df[['Smoking', 'Alcohol_Consumption', 'Diabetes', 'Hypertension', 'Family_History', 'Fasting_Blood_Sugar', 'Exercise_Induced_Angina']] = df[['Smoking', 'Alcohol_Consumption', 'Diabetes', 'Hypertension', 'Family_History', 'Fasting_Blood_Sugar', 'Exercise_Induced_Angina']].replace(0, 'No')

# %%
df[['Smoking', 'Alcohol_Consumption', 'Diabetes', 'Hypertension', 'Family_History', 'Fasting_Blood_Sugar', 'Exercise_Induced_Angina']] = df[['Smoking', 'Alcohol_Consumption', 'Diabetes', 'Hypertension', 'Family_History', 'Fasting_Blood_Sugar', 'Exercise_Induced_Angina']].replace(1, 'Yes')
df
# Out:
#        Age  Gender Smoking Alcohol_Consumption Physical_Activity_Level    BMI  \
# 0       69  Female     Yes                  No                Moderate  34.61
# 1       32    Male      No                  No                Moderate  22.75
# 2       89    Male      No                 Yes                Moderate  35.32
# 3       78    Male      No                 Yes                Moderate  18.23
# 4       38  Female     Yes                  No                Moderate  19.82
# ...    ...     ...     ...                 ...                     ...    ...
# 49995   21    Male      No                  No                     Low  39.93
# 49996   35  Female      No                  No                     Low  18.10
# 49997   46    Male      No                 Yes                    High  21.42
# 49998   56    Male      No                 Yes                     Low  29.93
# 49999   72    Male      No                  No                    High  30.85
#
# ...
